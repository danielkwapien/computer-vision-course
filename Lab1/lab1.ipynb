# %% [markdown]
# # LAB SESSION 1
#
# 1.1 MANAGING IMAGES IN PYTHON
# 1.2 COLOR
# 1.3 HISTOGRAMS
# 1.4 HISTOGRAM EQUALIZATION
# 1.5 FILTERS

# %% [markdown]
# ## 1. READING AND DISPLAYING IMAGES IN PYTHON
#
# ### READING IMAGES

# %%
import skimage
import matplotlib.pyplot as plt
from skimage import io
x = io.imread('peppers.png')
x_float = skimage.img_as_float(x)
x_uint = skimage.img_as_uint(x_float)

# %%
plt.imshow(x)
plt.show()

# %%
x = io.imread('dreamers.png')
plt.imshow(x, cmap='gray')
plt.show()

# %%
import numpy as np
x = io.imread('peppers.png')
x = np.array(x) 
x_red = x[:,:,0]
plt.imshow(x_red, cmap='jet')
plt.show()
